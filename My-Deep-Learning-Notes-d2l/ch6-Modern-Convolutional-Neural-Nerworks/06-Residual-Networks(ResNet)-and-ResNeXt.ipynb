# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l


class Residual(nn.Module):  #@save
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):# 要不要用1*1卷积层
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:# 如果使用1*1卷积层        
            # 把inputchannel变换到需要的channe数
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)# 使得高宽match
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        # conv1>>batch norm1>>relu
        Y = F.relu(self.bn1(self.conv1(X)))
        # 第2个batchnorm层
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X# X和Y 连在一起后 relu
        return F.relu(Y)

# %%
blk = Residual(3,3)
X = torch.rand(4, 3, 6, 6)
Y = blk(X)
Y.shape
# Out:
# torch.Size([4, 3, 6, 6])

# %%
blk = Residual(3,6, use_1x1conv=True, strides=2)
blk(X).shape
# Out:
# torch.Size([4, 6, 3, 3])

# %%
b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

# %%
#                                             需要多少个residual块

def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        else:# 只有前几个高宽减半
            blk.append(Residual(num_channels, num_channels))
    return blk

# %%
b2 = nn.Sequential(*resnet_block(64, 64, 2, first_block=True))
b3 = nn.Sequential(*resnet_block(64, 128, 2))
b4 = nn.Sequential(*resnet_block(128, 256, 2))
b5 = nn.Sequential(*resnet_block(256, 512, 2))

# %%
net = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Linear(512, 10))

# %%
# 高宽不变
# 剩下三个 通道数翻倍 高宽减半

X = torch.rand(size=(1, 1, 224, 224))
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 128, 28, 28])
# Sequential output shape:	 torch.Size([1, 256, 14, 14])
# Sequential output shape:	 torch.Size([1, 512, 7, 7])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 512, 1, 1])
# Flatten output shape:	 torch.Size([1, 512])
# Linear output shape:	 torch.Size([1, 10])

# %%
lr, num_epochs, batch_size = 0.05, 10, 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=96)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Desktop\Junior year first semester study materials\DataScience\DeepLearning\My-Learning-LiMu-DL\ch6-Modern-Convolutional-Neural-Nerworks\06-Residual-Networks(ResNet)-and-ResNeXt.ipynb 单元格 9 line 3
#       <a href='vscode-notebook-cell:/d%3A/Desktop/Junior%20year%20first%20semester%20study%20materials/DataScience/DeepLearning/My-Learning-LiMu-DL/ch6-Modern-Convolutional-Neural-Nerworks/06-Residual-Networks%28ResNet%29-and-ResNeXt.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> lr, num_epochs, batch_size = 0.05, 10, 256
#       <a href='vscode-notebook-cell:/d%3A/Desktop/Junior%20year%20first%20semester%20study%20materials/DataScience/DeepLearning/My-Learning-LiMu-DL/ch6-Modern-Convolutional-Neural-Nerworks/06-Residual-Networks%28ResNet%29-and-ResNeXt.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=96)
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/Junior%20year%20first%20semester%20study%20materials/DataScience/DeepLearning/My-Learning-LiMu-DL/ch6-Modern-Convolutional-Neural-Nerworks/06-Residual-Networks%28ResNet%29-and-ResNeXt.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> d2l.train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
#
# File d:\anaconda3\envs\d2l\lib\site-packages\d2l\torch.py:500, in train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
#     498 y_hat = net(X)
#     499 l = loss(y_hat, y)
# --> 500 l.backward()
#     501 optimizer.step()
#     502 with torch.no_grad():
#
# File d:\anaconda3\envs\d2l\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File d:\anaconda3\envs\d2l\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
